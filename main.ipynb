# %% [markdown]
# <a href="https://colab.research.google.com/github/LeandroFalasca/Explora-o-de-Dados/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Carregamento de Dados

# %%
df_customer = pd.read_csv("/content/customers_data.csv")
df_carbon = pd.read_csv("/content/carbon_offsets.csv")
df_rentals = pd.read_json("/content/rentals_data.json")
df_vehicles = pd.read_json("/content/vehicles_data.json")

# %%
df_customer.info()
df_customer.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    4 non-null      object
#  1   customer_type  4 non-null      object
#  2   age            3 non-null      float64
#  3   city           4 non-null      object
#  4   loyalty_score  4 non-null      int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 292.0+ bytes
#   customer_id customer_type   age       city  loyalty_score
# 0        C001    Recorrente  35.0  São Paulo             90
# 1        C002          Novo  28.0   Curitiba             60
# 2        C003          Novo   NaN   Salvador             50
# 3        C004   Corporativo  45.0  São Paulo             95

# %%
df_carbon.info()
df_carbon.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                2 non-null      int64
#  1   carbon_offset_tons  2 non-null      int64
#  2   cost_usd            2 non-null      int64
# dtypes: int64(3)
# memory usage: 180.0 bytes
#    year  carbon_offset_tons  cost_usd
# 0  2023                 120      1800
# 1  2024                 200      3000

# %%
df_rentals.info()
df_rentals.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rental_id    5 non-null      int64
#  1   customer_id  5 non-null      object
#  2   vehicle_id   5 non-null      object
#  3   start_date   5 non-null      object
#  4   end_date     5 non-null      object
#  5   city         5 non-null      object
#  6   daily_rate   5 non-null      int64
#  7   distance_km  5 non-null      int64
# dtypes: int64(3), object(5)
# memory usage: 452.0+ bytes
#    rental_id customer_id vehicle_id    start_date    end_date            city  \
# 0       2001        C001       V100    2024-01-05  2024-01-08       São Paulo
# 1       2002        C002       V101    2024/01/10  2024/01/12        Curitiba
# 2       2003        C003       V102  invalid_date  2024-01-15        Salvador
# 3       2004        C004       V103    2024-02-01  2024-02-10       São Paulo
# 4       2005        C001       V104    2024-02-15  2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km
# 0         180          320
# 1         150          210
# 2         220            0
# 3         300          980
# 4        -100          120

# %%
df_vehicles.info()
df_vehicles.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   vehicle_id    5 non-null      object
#  1   model         5 non-null      object
#  2   fuel_type     5 non-null      object
#  3   co2_g_per_km  4 non-null      float64
#  4   category      5 non-null      object
# dtypes: float64(1), object(4)
# memory usage: 332.0+ bytes
#   vehicle_id          model fuel_type  co2_g_per_km   category
# 0       V100           HB20  Gasolina         120.0  Econômico
# 1       V101        Corolla  Gasolina         160.0      Sedan
# 2       V102        Compass    Diesel         180.0        SUV
# 3       V103  Tesla Model 3  Elétrico           0.0   Elétrico
# 4       V104           Onix  Gasolina           NaN  Econômico

# %% [markdown]
# # Identificação de Dados
#
# - Datas
# - Valores Negativos
# - DataTypes

# %% [markdown]
# # Correções

# %% [markdown]
# 1. customers - age - valor ausente
# 2. rentals - daily_rate valor com < 0
# 3. vehicles - co2_g_per_km dado ausente
# 4. rentals - daily_rate esta como string
# 5. rentals - data invalida
# 6. rentals - data com formatação diferente

# %%
# 1.

media_idade = df_customer['age'].mean()
df_customer['age'] = df_customer['age'].fillna(media_idade)

display(df_customer)
# Out:
#   customer_id customer_type   age       city  loyalty_score
# 0        C001    Recorrente  35.0  São Paulo             90
# 1        C002          Novo  28.0   Curitiba             60
# 2        C003          Novo  36.0   Salvador             50
# 3        C004   Corporativo  45.0  São Paulo             95

# %%
# 2.
df_rentals.loc[df_rentals['daily_rate']<=0, 'daily_rate'] = pd.NA

display(df_rentals)
# Out:
#    rental_id customer_id vehicle_id    start_date    end_date            city  \
# 0       2001        C001       V100    2024-01-05  2024-01-08       São Paulo
# 1       2002        C002       V101    2024/01/10  2024/01/12        Curitiba
# 2       2003        C003       V102  invalid_date  2024-01-15        Salvador
# 3       2004        C004       V103    2024-02-01  2024-02-10       São Paulo
# 4       2005        C001       V104    2024-02-15  2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km
# 0       180.0          320
# 1       150.0          210
# 2       220.0            0
# 3       300.0          980
# 4         NaN          120

# %%
# 3.

df_vehicles['co2_g_per_km'] = df_vehicles['co2_g_per_km'].fillna(120)

display(df_vehicles)
# Out:
#   vehicle_id          model fuel_type  co2_g_per_km   category
# 0       V100           HB20  Gasolina         120.0  Econômico
# 1       V101        Corolla  Gasolina         160.0      Sedan
# 2       V102        Compass    Diesel         180.0        SUV
# 3       V103  Tesla Model 3  Elétrico           0.0   Elétrico
# 4       V104           Onix  Gasolina         120.0  Econômico

# %%
# 4.

df_rentals['daily_rate'] = pd.to_numeric(df_rentals['daily_rate'], errors='coerce')

display(df_rentals)
# Out:
#    rental_id customer_id vehicle_id    start_date    end_date            city  \
# 0       2001        C001       V100    2024-01-05  2024-01-08       São Paulo
# 1       2002        C002       V101    2024/01/10  2024/01/12        Curitiba
# 2       2003        C003       V102  invalid_date  2024-01-15        Salvador
# 3       2004        C004       V103    2024-02-01  2024-02-10       São Paulo
# 4       2005        C001       V104    2024-02-15  2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km
# 0       180.0          320
# 1       150.0          210
# 2       220.0            0
# 3       300.0          980
# 4         NaN          120

# %%
# 5.
df_rentals['start_date'] = pd.to_datetime(df_rentals['start_date'], errors="coerce")
df_rentals['end_date'] = pd.to_datetime(df_rentals['end_date'], errors="coerce")

display(df_rentals)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date            city  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km
# 0       180.0          320
# 1       150.0          210
# 2       220.0            0
# 3       300.0          980
# 4         NaN          120

# %%
# 6.

df_rentals['start_date'] = pd.to_datetime(df_rentals['start_date'], format='%y-%m-%d')

display(df_rentals)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date            city  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km
# 0       180.0          320
# 1       150.0          210
# 2       220.0            0
# 3       300.0          980
# 4         NaN          120

# %% [markdown]
# # Engenharia de Dados
#
# - Calcule a duração de cada locação (em dias).
# - Calcule a receita total por locação.
# - Faça o merge com a base de veiculos.
# - Calcule a emissão de CO² por locação
# - Extraia ano e mês de data de inicio da locação

# %%
# criar backup de dados
df_carbon_clean = df_carbon
df_rentals_clean = df_rentals
df_customer_clean = df_customer
df_vehicles_clean = df_vehicles

# %%
# Calcule a duração de cada locação (em dias).

df_rentals_clean['dias_locacao'] = (
    df_rentals_clean['end_date'] - df_rentals_clean['start_date']
).dt.days

display(df_rentals_clean)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date            city  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km  dias_locacao
# 0       180.0          320           3.0
# 1       150.0          210           NaN
# 2       220.0            0           NaN
# 3       300.0          980           9.0
# 4         NaN          120           1.0

# %%
# Calcule a receita total por locação.

df_rentals_clean['receita_total'] = (
    df_rentals_clean['dias_locacao'] * df_rentals_clean['daily_rate']
)

display(df_rentals_clean)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date            city  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km  dias_locacao  receita_total
# 0       180.0          320           3.0          540.0
# 1       150.0          210           NaN            NaN
# 2       220.0            0           NaN            NaN
# 3       300.0          980           9.0         2700.0
# 4         NaN          120           1.0            NaN

# %%
# Faça o merge com a base de veiculos.

df_consolidado = df_rentals_clean.merge(df_vehicles_clean, on='vehicle_id')

df_consolidado = df_consolidado.merge(df_customer_clean, on='customer_id')

display(df_consolidado)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date          city_x  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km  dias_locacao  receita_total          model  \
# 0       180.0          320           3.0          540.0           HB20
# 1       150.0          210           NaN            NaN        Corolla
# 2       220.0            0           NaN            NaN        Compass
# 3       300.0          980           9.0         2700.0  Tesla Model 3
# 4         NaN          120           1.0            NaN           Onix
#
#   fuel_type  co2_g_per_km   category customer_type   age     city_y  \
# 0  Gasolina         120.0  Econômico    Recorrente  35.0  São Paulo
# 1  Gasolina         160.0      Sedan          Novo  28.0   Curitiba
# 2    Diesel         180.0        SUV          Novo  36.0   Salvador
# 3  Elétrico           0.0   Elétrico   Corporativo  45.0  São Paulo
# 4  Gasolina         120.0  Econômico    Recorrente  35.0  São Paulo
#
#    loyalty_score
# 0             90
# 1             60
# 2             50
# 3             95
# 4             90

# %%
# Calcule a emissão de CO² por locação
df_consolidado['co2_emitido'] = df_consolidado['co2_g_per_km'] * df_consolidado['distance_km']

display(df_consolidado)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date          city_x  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km  dias_locacao  receita_total  ... co2_g_per_km  \
# 0       180.0          320           3.0          540.0  ...        120.0
# 1       150.0          210           NaN            NaN  ...        160.0
# 2       220.0            0           NaN            NaN  ...        180.0
# 3       300.0          980           9.0         2700.0  ...          0.0
# 4         NaN          120           1.0            NaN  ...        120.0
#
#     category  customer_type   age     city_y  loyalty_score  mes     ano  \
# 0  Econômico     Recorrente  35.0  São Paulo             90  1.0  2024.0
# 1      Sedan           Novo  28.0   Curitiba             60  NaN     NaN
# 2        SUV           Novo  36.0   Salvador             50  NaN     NaN
# 3   Elétrico    Corporativo  45.0  São Paulo             95  2.0  2024.0
# 4  Econômico     Recorrente  35.0  São Paulo             90  2.0  2024.0
#
#    dia_da_semana  co2_emitido
# 0            4.0      38400.0
# 1            NaN      33600.0
# 2            NaN          0.0
# 3            3.0          0.0
# 4            3.0      14400.0
#
# [5 rows x 22 columns]

# %%
# Extraia ano e mês de data de inicio da locação
df_consolidado['mes'] = df_consolidado['start_date'].dt.month
df_consolidado['ano'] = df_consolidado['start_date'].dt.year
df_consolidado['dia_da_semana'] = df_consolidado['start_date'].dt.weekday

display(df_consolidado)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date          city_x  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km  dias_locacao  receita_total  ... fuel_type  \
# 0       180.0          320           3.0          540.0  ...  Gasolina
# 1       150.0          210           NaN            NaN  ...  Gasolina
# 2       220.0            0           NaN            NaN  ...    Diesel
# 3       300.0          980           9.0         2700.0  ...  Elétrico
# 4         NaN          120           1.0            NaN  ...  Gasolina
#
#   co2_g_per_km   category customer_type   age     city_y loyalty_score  mes  \
# 0        120.0  Econômico    Recorrente  35.0  São Paulo            90  1.0
# 1        160.0      Sedan          Novo  28.0   Curitiba            60  NaN
# 2        180.0        SUV          Novo  36.0   Salvador            50  NaN
# 3          0.0   Elétrico   Corporativo  45.0  São Paulo            95  2.0
# 4        120.0  Econômico    Recorrente  35.0  São Paulo            90  2.0
#
#       ano  dia_da_semana
# 0  2024.0            4.0
# 1     NaN            NaN
# 2     NaN            NaN
# 3  2024.0            3.0
# 4  2024.0            3.0
#
# [5 rows x 21 columns]
